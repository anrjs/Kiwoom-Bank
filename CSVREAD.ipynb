# %%
import pandas as pd

# %%
df = pd.read_csv("metrics_result.csv", dtype={"stock_code": str}, encoding="utf-8-sig")
df["stock_code"] = df["stock_code"].str.zfill(6)
df = df.set_index("stock_code")

# %%
df.to_excel("stock.xlsx")

# %%
df
# Out:
#            debt_ratio equity_ratio debt_dependency_ratio current_ratio  \
# stock_code
# 005380        182.52%        35.4%                47.14%        145.6%
# 079550         395.0%        20.2%                  4.6%        84.36%
# 023530        128.98%       43.67%                25.54%        56.09%
# 003490        328.82%       23.32%                46.58%        68.44%
# 086520        112.02%       47.17%                 0.27%        121.5%
# 004710         71.75%       58.22%                13.71%       123.38%
# 042660         266.9%       27.26%                 2.66%       108.69%
# 336260        136.45%       42.29%                36.25%       180.51%
# 001070         40.09%       71.38%                16.04%       166.71%
# 143210        420.82%        19.2%                 55.0%        50.98%
# 290120        184.11%        35.2%                 16.9%       123.73%
#
#            quick_ratio  interest_coverage_ratio  ebitda_to_total_debt  \
# stock_code
# ...
